# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameer240725/ALGORITHM-LAB/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.

# %%
import timeit
import random
import matplotlib.pyplot as plt

def selection_sort(arr):
    """
    Sorts a list using the Selection Sort algorithm (in-place).
    """
    n = len(arr)
    for i in range(n - 1):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
n_values_selection_test = [10, 100, 500, 1000, 2000]
times_selection_test = []

for n in n_values_selection_test:

    data_selection_test = [random.randint(0, 10000) for _ in range(n)]

    start_time = timeit.default_timer()
    selection_sort(data_selection_test.copy())
    end_time = timeit.default_timer()
    times_selection_test.append((end_time - start_time) * 1000)
plt.figure(figsize=(10, 6))
plt.plot(n_values_selection_test, times_selection_test, marker='o', linestyle='-')
plt.title("Selection Sort Running Time vs. Input Size (n)")
plt.xlabel("Input Size (n)")
plt.ylabel("Time (ms)")
plt.grid(True)
plt.show()

print("Selection sort times for different n values (ms):")
for n, t in zip(n_values_selection_test, times_selection_test):
    print(f"n={n}: {t:.4f} ms")
# Out:
# Selection sort times for different n values (ms):
# n=10: 0.0115 ms
# n=100: 0.4650 ms
# n=500: 6.7881 ms
# n=1000: 26.5326 ms
# n=2000: 95.9929 ms

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.

# %%
import timeit
import random
import matplotlib.pyplot as plt

def partition(arr, low, high):
    i = (low - 1)
    pivot = arr[high]

    for j in range(low, high):
        if arr[j] <= pivot:
            i = i + 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return (i + 1)

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)


n_values_quick_test = [10, 100, 500, 1000, 2000]
times_quick_test = []

for n in n_values_quick_test:

    data_quick_test = [random.randint(0, 10000) for _ in range(n)]

    arr_to_sort = data_quick_test.copy()
    start_time = timeit.default_timer()
    quick_sort(arr_to_sort, 0, len(arr_to_sort) - 1)
    end_time = timeit.default_timer()
    times_quick_test.append((end_time - start_time) * 1000)

plt.figure(figsize=(10, 6))
plt.plot(n_values_quick_test, times_quick_test, marker='o', linestyle='-')
plt.title("Quick Sort Running Time vs. Input Size (n)")
plt.xlabel("Input Size (n)")
plt.ylabel("Time (ms)")
plt.grid(True)
plt.show()

print("Quick sort times for different n values (ms):")
for n, t in zip(n_values_quick_test, times_quick_test):
    print(f"n={n}: {t:.4f} ms")
# Out:
# Quick sort times for different n values (ms):
# n=10: 0.0170 ms
# n=100: 0.1042 ms
# n=500: 0.4459 ms
# n=1000: 1.0791 ms
# n=2000: 3.5001 ms

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
import datetime
import random

# Creating a random value (uniform)
ms = datetime.datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))

# %%
import copy # Added import statement for copy module

a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a, 0, len(a) - 1) # Corrected quick_sort call with low and high parameters
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b) # This will be defined in the next cell
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    selection_sort(c) # Corrected to call selection_sort function
    c_time.append((timeit.default_timer() - start_time) * 1000)

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-716276353.py in <cell line: 0>()
#       4 plt.plot(b_time, linewidth = 1, marker="o")
#       5 plt.plot(c_time, linewidth = 1, marker="o")
# ----> 6 plt.xticks(np.arange(len(n_list)), n_list)
#       7 plt.title("Compare Sorting Algorithms", fontsize = 14)
#       8 plt.ylabel('Time (ms)')
#
# NameError: name 'np' is not defined

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
